# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cf56efcc-8c6d-460c-bc7e-e6a866c3dc5a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cf56efcc-8c6d-460c-bc7e-e6a866c3dc5a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
uploaded

# %%
COVID = pd.read_csv('COVID-19 Coronavirus.csv', sep=',')

# %%
COVID.head(10)
# Out:
#                Country          Other names ISO 3166-1 alpha-3 CODE  \
# 0          Afghanistan          Afghanistan                     AFG
# 1              Albania              Albania                     ALB
# 2              Algeria              Algeria                     DZA
# 3              Andorra              Andorra                     AND
# 4               Angola               Angola                     AGO
# 5             Anguilla             Anguilla                     AIA
# 6  Antigua and Barbuda  Antigua and Barbuda                     ATG
# 7            Argentina            Argentina                     ARG
# 8              Armenia              Armenia                     ARM
# 9                Aruba                Aruba                     ABW
#
#    Population                        Continent  Total Cases  Total Deaths  \
# 0    40462186                             Asia       177827          7671
# ...

# %%
COVID.describe()
# Out:
#          Population   Total Cases  Total Deaths  Tot Cases//1M pop  \
# count  2.250000e+02  2.250000e+02  2.250000e+02         225.000000
# mean   3.507321e+07  2.184781e+06  2.744813e+04      136900.373333
# std    1.392418e+08  7.275938e+06  9.689177e+04      145060.340289
# min    8.050000e+02  1.000000e+00  0.000000e+00           9.000000
# 25%    5.665570e+05  2.407100e+04  1.890000e+02       11384.000000
# 50%    5.827911e+06  1.639360e+05  1.965000e+03       88987.000000
# 75%    2.190585e+07  1.092547e+06  1.366000e+04      223335.000000
# max    1.439324e+09  8.183905e+07  1.008222e+06      696044.000000
#
#        Tot Deaths/1M pop  Death percentage
# count         225.000000        225.000000
# mean         1096.715556          1.444125
# std          1195.715543          1.741728
# min             0.000000          0.000000
# 25%           123.000000          0.511291
# 50%           708.000000          1.036905
# 75%          1795.000000          1.977017
# ...

# %%
COVID['Population'].plot(kind='box',vert=False, figsize=(15,5))

# %%
COVID['Population'].plot(kind='box',vert=True, figsize=(15,5))

# %%
COVID['Total Cases'].plot(kind='density', figsize=(15,5))

# %%
ax = COVID['Death percentage'].plot(kind='density', figsize=(15,5))
ax.axvline(COVID['Death percentage'].mean(),color = 'yellow')
ax.axvline(COVID['Death percentage'].median(),color = 'green')

# %%
 ax = COVID['Population'].plot(kind='hist', figsize=(15,5))
ax.set_ylabel('Number of population')
ax.set_xlabel('Population')
# Out:
# Text(0.5, 0, 'Population')

# %%
COVID['Continent'].value_counts()
# Out:
# Africa                             58
# Asia                               49
# Europe                             48
# Latin America and the Caribbean    48
# Oceania                            17
# Northern America                    5
# Name: Continent, dtype: int64

# %%
 COVID['Continent'].value_counts().plot(kind='pie', figsize=(8,8), autopct='%1.2f%%', title='Average Continent Distrubution')

# %%
ax = COVID['Continent'].value_counts().plot(kind='bar', figsize=(7,7))
ax.set_ylabel('Range of Continents')
ax.set_xlabel('Continent')
# Out:
# Text(0.5, 0, 'Continent')

# %%
corr = COVID.corr()

# %%
corr
# Out:
#                    Population  Total Cases  Total Deaths  Tot Cases//1M pop  \
# Population           1.000000     0.430687      0.428189          -0.130130
# Total Cases          0.430687     1.000000      0.915263           0.127890
# Total Deaths         0.428189     0.915263      1.000000           0.036561
# Tot Cases//1M pop   -0.130130     0.127890      0.036561           1.000000
# Tot Deaths/1M pop   -0.066485     0.216272      0.289201           0.508630
# Death percentage     0.083387    -0.032520      0.082616          -0.349986
#
#                    Tot Deaths/1M pop  Death percentage
# Population                 -0.066485          0.083387
# Total Cases                 0.216272         -0.032520
# Total Deaths                0.289201          0.082616
# Tot Cases//1M pop           0.508630         -0.349986
# Tot Deaths/1M pop           1.000000          0.061088
# Death percentage            0.061088          1.000000

# %%
fig =plt.figure(figsize=(5,5))
plt.matshow(corr, cmap='RdBu', fignum = fig.number)
plt.xticks(range(len(corr.columns)), corr.columns, rotation = 'vertical');
plt.yticks(range(len(corr.columns)),corr.columns);

# %%
COVID.plot(kind='scatter', x='Total Cases', y='Total Deaths', figsize=(7,7))

# %%
ax = COVID[['Total Cases','Total Deaths']].boxplot(by='Total Cases', figsize=(10,6))
ax.set_ylabel('Total Deaths')
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
# Text(0, 0.5, 'Total Deaths')

# %%
boxplot_cols = ['Total Cases', 'Total Deaths', 'Death percentage']

# %%
COVID[boxplot_cols].plot(kind='box', subplots=True, layout=(2,3), figsize=(15,8))
# Out:
# Total Cases            AxesSubplot(0.125,0.536818;0.227941x0.343182)
# Total Deaths        AxesSubplot(0.398529,0.536818;0.227941x0.343182)
# Death percentage    AxesSubplot(0.672059,0.536818;0.227941x0.343182)
# dtype: object

# %%
 COVID['Death percentage'].plot(kind='line', figsize=(15,5))

# %%
sns.relplot(x='Population', y='Total Cases', data=COVID)

# %%
S

# %%
sns.relplot(x = 'Total Cases', y = 'Total Deaths', kind='line', data=COVID)

# %%
COVID.columns
# Out:
# Index(['Country', 'Other names', 'ISO 3166-1 alpha-3 CODE', 'Population',
#        'Continent', 'Total Cases', 'Total Deaths', 'Tot Cases//1M pop',
#        'Tot Deaths/1M pop', 'Death percentage'],
#       dtype='object')

# %%
sns.catplot(x = 'Country', y = 'Population', data=COVID)

# %%
sns.relplot(x='Total Cases', y = 'Death percentage', data = COVID)

# %%
c = COVID.corr()
c
# Out:
#                    Population  Total Cases  Total Deaths  Tot Cases//1M pop  \
# Population           1.000000     0.430687      0.428189          -0.130130
# Total Cases          0.430687     1.000000      0.915263           0.127890
# Total Deaths         0.428189     0.915263      1.000000           0.036561
# Tot Cases//1M pop   -0.130130     0.127890      0.036561           1.000000
# Tot Deaths/1M pop   -0.066485     0.216272      0.289201           0.508630
# Death percentage     0.083387    -0.032520      0.082616          -0.349986
#
#                    Tot Deaths/1M pop  Death percentage
# Population                 -0.066485          0.083387
# Total Cases                 0.216272         -0.032520
# Total Deaths                0.289201          0.082616
# Tot Cases//1M pop           0.508630         -0.349986
# Tot Deaths/1M pop           1.000000          0.061088
# Death percentage            0.061088          1.000000

# %%
sns.heatmap(c, cmap = 'Accent_r', annot=True)

# %%
sns.distplot(c['Death percentage'], bins = 8, kde = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(c['Death percentage'], bins = 8, kde = True)

# %%
sns.countplot(c['Population'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(c['Total Cases'], hue = c['Total Deaths'], dodge = True,)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.jointplot(x = COVID['Population'], y = COVID['Death percentage'])

# %%
sns.jointplot(x = c['Population'], y = c['Tot\xa0Cases//1M pop'], hue = c['Tot\xa0Deaths/1M pop'])

# %%
sns.jointplot(x = c['Tot\xa0Cases//1M pop'], y = c['Tot\xa0Deaths/1M pop'], kind = 'hex')

# %%
sns.jointplot(x = c['Population'], y = c['Death percentage'], kind = 'hist')

# %%
sns.jointplot(x = c['Total Cases'], y = c['Total Deaths'], kind = 'kde')

# %%
sns.jointplot(x = c['Population'], y = c['Total Deaths'], kind = 'resid')

# %%
sns.barplot(x = c['Total Cases'], y = c['Total Deaths'])

# %%
sns.boxplot(c['Death percentage'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.catplot(x = 'Population', y = 'Death percentage', kind='bar', data=c)

# %%
sns.barplot(c)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.relplot(x = 'Population', y = 'Death percentage', hue = 'Total Cases', data = c)

# %%
c.hist(figsize=(12,10));
plt.show()

# %%
sns.countplot(data=c, x = 'Population', dodge = 'Total Cases', hue = 'Total Deaths');

# %%
ax = sns.violinplot(x = 'Population', y = 'Death percentage', data = c, size = 8)

# %%
sns.kdeplot(c['Population'])

# %%
sns.histplot(x= c['Death percentage'])

# %%
sns.countplot(c['Total Cases'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(x=c['Population'], y=c['Death percentage'])

# %%
sns.scatterplot(x=c['Population'], y=c['Death percentage'], hue=c['Total Cases'])
